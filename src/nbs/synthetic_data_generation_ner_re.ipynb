# %% [markdown]
# # **Using LLMs to Generate Synthetic Data for Fine-Tuning GLiNER (NER + Relation Extraction)**
#
# This notebook demonstrates a straightforward approach to generating synthetic training data for fine-tuning GLiNER on both Named Entity Recognition (NER) and Relation Extraction (RE).
#
# We focus on creating **fully synthetic examples**, including both the input text and corresponding annotations. However, if you already have high-quality text from your target domain, you can also use an LLM to **annotate your existing data** instead.

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
AWS_ACCESS_KEY_ID = user_secrets.get_secret("AWS_ACCESS_KEY_ID")
AWS_SECRET_ACCESS_KEY = user_secrets.get_secret("AWS_SECRET_ACCESS_KEY")
HF_TOKEN = user_secrets.get_secret("HF_TOKEN")
OPENAI_API_KEY = user_secrets.get_secret("OPENAI_API_KEY")

# %%
import boto3
import os
import json
import re
from typing import List, Dict, Tuple, Optional, Union, Any

# ── S3 CONFIG ─────────────────────────────────────────────────────────────────
s3 = boto3.client(
    "s3",
    aws_access_key_id     = AWS_ACCESS_KEY_ID,
    aws_secret_access_key = AWS_SECRET_ACCESS_KEY,
    region_name           = "ap-southeast-2",
)
BUCKET       = "doccano-processed"
INIT_KEY     = "gradio/initial_data_train.json"
VALID_PREFIX = "validated_records/"

# %%
def load_initial_data() -> List[Dict]:
    obj = s3.get_object(Bucket=BUCKET, Key=INIT_KEY)
    return json.loads(obj['Body'].read())

def load_all_validations() -> Dict[int, Dict]:
    records = {}
    pages = s3.get_paginator("list_objects_v2").paginate(
        Bucket=BUCKET, Prefix=VALID_PREFIX
    )
    for page in pages:
        for obj in page.get("Contents", []):
            key = obj["Key"]
            idx = int(os.path.splitext(os.path.basename(key))[0])
            data = s3.get_object(Bucket=BUCKET, Key=key)["Body"].read()
            records[idx] = json.loads(data)
    return records

# %%
data             = load_initial_data()
validated_store  = load_all_validations()

# %%
validated_store = load_all_validations()
validated_store = {idx:doc for idx, doc in validated_store.items() if idx <= 150}

# %%
len(validated_store)
# Out:
# 150

# %%
len(data)
# Out:
# 783

# %% [markdown]
# # Create the DataFrame

# %%
import pandas as pd
df = pd.DataFrame.from_dict(validated_store, orient='index')
df.index.name = 'idx'                        
df.reset_index(inplace=True)

# %%
df.loc[df['validated'] == True].shape
# Out:
# (148, 5)

# %%
validated_df = df.loc[df['validated'] == True]

# %%
validated_df = validated_df.loc[validated_df['ner'].apply(lambda x: x != [])]

# %%
filtered_df = validated_df.copy()

# %%
filtered_df.head()
# Out:
#    idx                                               text  \
# 0    0  displacement has been decreasing slowly in con...
# 1    1  non-cooperative behaviors that lead to the eme...
# 2   10  3 Figure 1 Emigration is highest for middle-in...
# 3  100  displaced children and adolescents residing in...
# 4  101  9 and the Syrian crisis , the UNHCR and the Wo...
#
#                                       tokenized_text  \
# 0  [displacement, has, been, decreasing, slowly, ...
# 1  [non-cooperative, behaviors, that, lead, to, t...
# 2  [3, Figure, 1, Emigration, is, highest, for, m...
# 3  [displaced, children, and, adolescents, residi...
# 4  [9, and, the, Syrian, crisis, ,, the, UNHCR, a...
#
#                                                  ner  validated
# 0  [[19, 19, match_named], [24, 28, RUV <> descri...       True
# 1  [[41, 51, unique dataset on refugee camps <> d...       True
# 2  [[15, 16, labelled_unnamed], [18, 19, migratio...       True
# 3  [[17, 17, match_named], [40, 68, VenRePs-Kids ...       True
# 4  [[51, 51, proGres <> geography], [52, 52, matc...       True

# %%
def has_document_in_ner(ner_list):
    for entity in ner_list:
        if len(entity) >= 3 and "document" in entity[2].lower():
            return True
    return False

# %%
filtered_df[filtered_df["ner"].apply(has_document_in_ner)]
# Out:
# Empty DataFrame
# Columns: [idx, text, tokenized_text, ner, validated]
# Index: []

# %%
def join_tokens(tokens):
    # Joining tokens with space, but handling special characters correctly
    text = ""
    for token in tokens:
        if token in {",", ".", "!", "?", ":", ";", "..."}:
            text = text.rstrip() + token
        else:
            text += " " + token
    return text.strip()

# %%
train_df = filtered_df.copy()
train_df.head()
# Out:
#    idx                                               text  \
# 0    0  displacement has been decreasing slowly in con...
# 1    1  non-cooperative behaviors that lead to the eme...
# 2   10  3 Figure 1 Emigration is highest for middle-in...
# 3  100  displaced children and adolescents residing in...
# 4  101  9 and the Syrian crisis , the UNHCR and the Wo...
#
#                                       tokenized_text  \
# 0  [displacement, has, been, decreasing, slowly, ...
# 1  [non-cooperative, behaviors, that, lead, to, t...
# 2  [3, Figure, 1, Emigration, is, highest, for, m...
# 3  [displaced, children, and, adolescents, residi...
# 4  [9, and, the, Syrian, crisis, ,, the, UNHCR, a...
#
#                                                  ner  validated
# 0  [[19, 19, match_named], [24, 28, RUV <> descri...       True
# 1  [[41, 51, unique dataset on refugee camps <> d...       True
# 2  [[15, 16, labelled_unnamed], [18, 19, migratio...       True
# 3  [[17, 17, match_named], [40, 68, VenRePs-Kids ...       True
# 4  [[51, 51, proGres <> geography], [52, 52, matc...       True

# %%
del filtered_df

# %%
dataset_map = {
    # named variants
    'match_named':   'named dataset',
    'pred_named':    'named dataset',
    'actual_named':  'named dataset',
    # unnamed variants
    'match_unnamed': 'unnamed dataset',
    'pred_unnamed':  'unnamed dataset',
    'actual_unnamed':'unnamed dataset',
    # vague variants
    'match_vague':   'vague dataset',
    'pred_vague':    'vague dataset',
    'actual_vague':  'vague dataset',
    # labelled override
'labelled_named': 'named dataset',
'labelled_vague': 'vague dataset',
'labelled_unnamed': 'unnamed dataset',

}

# map wrongly labelled relations
rel_map = {
    'year':       'reference year',
    'years':      'reference year',
    'demography': 'geography',
}

def normalize_ner(ner_list):
    normalized = []
    for start, end, label in ner_list:
        # if it’s a dataset‐tag, collapse it immediately
        if label in dataset_map:
            normalized.append((start, end, dataset_map[label]))
            continue

        # if it’s a relation, normalize only the right side
        if '<>' in label:
            parts = label.split(',')
            out_pieces = []
            for part in parts:
                part = part.strip()
                if '<>' not in part:
                    continue
                subj, rel = part.split('<>', 1)
                subj = subj.strip()
                rel  = rel.strip().lower()
                rel  = rel_map.get(rel, rel)
                out_pieces.append(f"{subj} <> {rel}")
            if out_pieces:
                normalized.append((start, end, ', '.join(out_pieces)))
            continue

        # otherwise, leave it
        normalized.append((start, end, label))

    return normalized

# %%
train_df['ner_normalized'] = train_df['ner'].apply(normalize_ner)

# %%
def extract_text(row):
    tokenized = row['tokenized_text']
    ner_entries = row['ner_normalized']
    extracted = []

    for start_idx, end_idx, label in ner_entries:
        # rebuild the actual text span
        span_text = " ".join(tokenized[start_idx : end_idx + 1])

        # split out multiple labels if they’re comma-separated
        pieces = [piece.strip() for piece in label.split(", ") if piece.strip()]
        for piece in pieces:
            extracted.append({
                "text":  span_text,
                "label": piece
            })

    return extracted

train_df["extracted_text"] = train_df.apply(extract_text, axis=1)

# %%
train_df.iloc[4]['text']
# Out:
# '9 and the Syrian crisis , the UNHCR and the World Food Program ( WFP ) have been conducting a variety of surveys as well as extensive home visits that allowed researchers to analyze refugee conditions as had never been done before . The paper uses two data sets : the Jordan proGres registration system ( PG for short ) as of December 2014 and the Jordan Home Visits survey , round II data ( HV for short ) collected between November 2013 and September 2014 . Both data sets were provided by the UNHCR in the context of the joint World Bank-UNHCR study on the welfare of Syrian refugees ( Verme et al . , 2016 ) . These comprehensive data sets have the distinct advantage that they can be linked by a common identification number . We can therefore trace the same individuals and households across the two sources of data . The proGres registration system is what we consider the “ census ” of refugees . This data set has no information on consumption but contains socio-economic characteristics for all registered individuals and households . Variables available in the PG data include , among others'

# %%
train_df.iloc[4]['ner_normalized']
# Out:
# [(51, 51, 'proGres <> geography'),
#  (52, 52, 'named dataset'),
#  (53, 54, 'proGres <> data type'),
#  (56, 56, 'proGres <> acronym'),
#  (63, 63, 'proGres <> reference year'),
#  (66, 66, 'Home Visits survey <> geography'),
#  (67, 69, 'named dataset'),
#  (71, 72, 'Home Visits survey <> version'),
#  (75, 75, 'Home Visits survey <> acronym'),
#  (82, 82, 'Home Visits survey <> reference year'),
#  (85, 85, 'Home Visits survey <> reference year'),
#  (94, 94, 'proGres <> publisher, Home Visits survey <> publisher'),
#  (99, 103, 'proGres <> data source, Home Visits survey <> data source'),
#  (155, 155, 'named dataset'),
#  (156, 157, 'proGres <> data type'),
#  (163, 167, 'proGres <> description'),
#  (178, 186, 'proGres <> description'),
#  (192, 192, 'named dataset')]

# %%
train_df.iloc[4]['extracted_text']
# Out:
# [{'text': 'Jordan', 'label': 'proGres <> geography'},
#  {'text': 'proGres', 'label': 'named dataset'},
#  {'text': 'registration system', 'label': 'proGres <> data type'},
#  {'text': 'PG', 'label': 'proGres <> acronym'},
#  {'text': '2014', 'label': 'proGres <> reference year'},
#  {'text': 'Jordan', 'label': 'Home Visits survey <> geography'},
#  {'text': 'Home Visits survey', 'label': 'named dataset'},
#  {'text': 'round II', 'label': 'Home Visits survey <> version'},
#  {'text': 'HV', 'label': 'Home Visits survey <> acronym'},
#  {'text': '2013', 'label': 'Home Visits survey <> reference year'},
#  {'text': '2014', 'label': 'Home Visits survey <> reference year'},
#  {'text': 'UNHCR', 'label': 'proGres <> publisher'},
#  {'text': 'UNHCR', 'label': 'Home Visits survey <> publisher'},
#  {'text': 'the joint World Bank-UNHCR study',
#   'label': 'proGres <> data source'},
#  {'text': 'the joint World Bank-UNHCR study',
#   'label': 'Home Visits survey <> data source'},
#  {'text': 'proGres', 'label': 'named dataset'},
#  {'text': 'registration system', 'label': 'proGres <> data type'},
#  {'text': '“ census ” of refugees', 'label': 'proGres <> description'},
#  {'text': 'contains socio-economic characteristics for all registered individuals and households',
#   'label': 'proGres <> description'},
#  {'text': 'PG', 'label': 'named dataset'}]

# %% [markdown]
# ## Synthetic data generation

# %%
from openai import OpenAI
from google.colab import userdata
from kaggle_secrets import UserSecretsClient
import os
import json
from typing import List, Set, Dict
# Set up OpenAI API key
user_secrets = UserSecretsClient()
os.environ['OPENAI_API_KEY'] = user_secrets.get_secret("OPENAI_API_KEY")
os.environ['HF_TOKEN'] = user_secrets.get_secret("HF_TOKEN")
# Initialize OpenAI client
client = OpenAI()
model = 'gpt-4o-mini'  # gpt-4o-mini-2024-07-18

# %%
from huggingface_hub import login
login(token=os.environ['HF_TOKEN'])
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %% [markdown]
# ## Prompting function

# %%
train_df.sample(10)
# Out:
#      idx                                               text  \
# 19   115  model of expectations in the following section...
# 139    9  ) Source : Authors ’ calculations with data fr...
# 121   73  which to believe that diﬀerent types of interv...
# 4    101  9 and the Syrian crisis , the UNHCR and the Wo...
# 105   59  Table 1 : The fraction of messages from return...
# 15   111  4 Data and descriptive statistics Primary data...
# 82    38  , with 55 % falling between 20 and 24 years . ...
# 28   123  into 47 sub-national units . Locations in Ugan...
# 9    106  that were surveyed only in the ESS1 are exclud...
# 53   146  12 Figure 2 . Poverty Estimates , by year and ...
#
#                                         tokenized_text  \
# 19   [model, of, expectations, in, the, following, ...
# 139  [), Source, :, Authors, ’, calculations, with,...
# 121  [which, to, believe, that, diﬀerent, types, of...
# 4    [9, and, the, Syrian, crisis, ,, the, UNHCR, a...
# 105  [Table, 1, :, The, fraction, of, messages, fro...
# 15   [4, Data, and, descriptive, statistics, Primar...
# 82   [,, with, 55, %, falling, between, 20, and, 24...
# 28   [into, 47, sub-national, units, ., Locations, ...
# 9    [that, were, surveyed, only, in, the, ESS1, ar...
# 53   [12, Figure, 2, ., Poverty, Estimates, ,, by, ...
#
#                                                    ner  validated  \
# 19   [[11, 14, labelled_named], [15, 18, Foreign In...       True
# 139  [[9, 9, LFS <> geography], [10, 10, match_name...       True
# 121  [[74, 74, socio-economic household surveys <> ...       True
# 4    [[51, 51, proGres <> geography], [52, 52, matc...       True
# 105  [[142, 157, Researcher Coded dataset <> descri...       True
# 15   [[14, 14, Refugee and Host Communities Househo...       True
# 82   [[107, 108, DHS survey <> data type], [111, 11...       True
# 28   [[7, 7, GWP <> geography], [88, 88, match_named]]       True
# 9    [[6, 6, match_named], [21, 21, match_named], [...       True
# 53   [[64, 64, LFS <> geography], [88, 88, match_na...       True
#
#                                         ner_normalized  \
# 19   [(11, 14, named dataset), (15, 18, Foreign Inv...
# 139  [(9, 9, LFS <> geography), (10, 10, named data...
# 121  [(74, 74, socio-economic household surveys <> ...
# 4    [(51, 51, proGres <> geography), (52, 52, name...
# 105  [(142, 157, Researcher Coded dataset <> descri...
# 15   [(14, 14, Refugee and Host Communities Househo...
# 82   [(107, 108, DHS survey <> data type), (111, 11...
# 28   [(7, 7, GWP <> geography), (88, 88, named data...
# 9    [(6, 6, named dataset), (21, 21, named dataset...
# 53   [(64, 64, LFS <> geography), (88, 88, named da...
#
#                                         extracted_text
# 19   [{'text': 'Foreign Investment During Recovery'...
# 139  [{'text': 'Jordan', 'label': 'LFS <> geography...
# 121  [{'text': 'UNHCR', 'label': 'socio-economic ho...
# 4    [{'text': 'Jordan', 'label': 'proGres <> geogr...
# 105  [{'text': 'set of groups which mention locatio...
# 15   [{'text': 'Uganda', 'label': 'Refugee and Host...
# 82   [{'text': 'national figures', 'label': 'DHS su...
# 28   [{'text': 'Uganda', 'label': 'GWP <> geography...
# 9    [{'text': 'ESS1', 'label': 'named dataset'}, {...
# 53   [{'text': 'Turkey', 'label': 'LFS <> geography...

# %%
train_df.shape
# Out:
# (136, 7)

# %%
train_df['entities'] = train_df['extracted_text']

# %%
train_df['ner'] = train_df['ner_normalized']

# %%
train_df.head()
# Out:
#    idx                                               text  \
# 0    0  displacement has been decreasing slowly in con...
# 1    1  non-cooperative behaviors that lead to the eme...
# 2   10  3 Figure 1 Emigration is highest for middle-in...
# 3  100  displaced children and adolescents residing in...
# 4  101  9 and the Syrian crisis , the UNHCR and the Wo...
#
#                                       tokenized_text  \
# 0  [displacement, has, been, decreasing, slowly, ...
# 1  [non-cooperative, behaviors, that, lead, to, t...
# 2  [3, Figure, 1, Emigration, is, highest, for, m...
# 3  [displaced, children, and, adolescents, residi...
# 4  [9, and, the, Syrian, crisis, ,, the, UNHCR, a...
#
#                                                  ner  validated  \
# 0  [(19, 19, named dataset), (24, 28, RUV <> desc...       True
# 1  [(41, 51, unique dataset on refugee camps <> d...       True
# 2  [(15, 16, unnamed dataset), (18, 19, migration...       True
# 3  [(17, 17, named dataset), (40, 68, VenRePs-Kid...       True
# 4  [(51, 51, proGres <> geography), (52, 52, name...       True
#
#                                       ner_normalized  \
# 0  [(19, 19, named dataset), (24, 28, RUV <> desc...
# 1  [(41, 51, unique dataset on refugee camps <> d...
# 2  [(15, 16, unnamed dataset), (18, 19, migration...
# 3  [(17, 17, named dataset), (40, 68, VenRePs-Kid...
# 4  [(51, 51, proGres <> geography), (52, 52, name...
#
#                                       extracted_text  \
# 0  [{'text': 'RUV', 'label': 'named dataset'}, {'...
# 1  [{'text': 'assess the consequences of forced m...
# 2  [{'text': 'migration data', 'label': 'unnamed ...
# 3  [{'text': 'VenRePs-Kids', 'label': 'named data...
# 4  [{'text': 'Jordan', 'label': 'proGres <> geogr...
#
#                                             entities
# 0  [{'text': 'RUV', 'label': 'named dataset'}, {'...
# 1  [{'text': 'assess the consequences of forced m...
# 2  [{'text': 'migration data', 'label': 'unnamed ...
# 3  [{'text': 'VenRePs-Kids', 'label': 'named data...
# 4  [{'text': 'Jordan', 'label': 'proGres <> geogr...

# %%
from collections import Counter

label_counter = Counter()

for item in train_df[['ner']].to_dict(orient='records'):
    for ner in item.get('ner', []):
        label_counter[ner[2]] += 1

# Print sorted by frequency
for label, count in label_counter.most_common():
    print(f"{label}: {count}")
# Out:
# named dataset: 267
# unnamed dataset: 32
# vague dataset: 19
# RDHS <> reference year: 12
# FDP datasets <> geography: 10
# Kagera Health and Development Survey <> geography: 10
# survey data <> reference year: 8
# Armed Conflict Survey <> geography: 8
# UNHCR Camp Mapping database <> geography: 8
# LFS <> reference year: 7
# International Migration Organization Displacement Tracking Matrix dataset <> geography: 7
# PISA <> geography: 7
# Cadastro ´ Unico <> geography: 6
# Poll 14 <> geography: 5
# LFS <> geography: 5
# ESS <> reference year: 5
# PWT <> reference year: 4
# Demographic and Health Survey <> reference year: 4
# SYPJ <> reference year: 4
# Listening to Displaced People Survey <> geography: 4
# refugee registration data <> geography: 4
# 2009 census <> geography: 4
# European Social Survey <> geography: 4
# Penn World Tables <> data type: 3
# World Bank survey <> geography: 3
# Demographic and Health Survey <> data type: 3
# JLMPS <> reference year: 3
# Gallup World Poll <> reference year: 3
# Gallup World Poll <> geography: 3
# Skills Profile Survey <> geography: 3
# Labor Force Survey <> geography: 3
# Labor Force Survey <> reference year: 3
# Structural Surveys <> reference year: 3
# SISMIGRA <> geography: 3
# study dataset <> geography: 3
# Listening to Displaced People Survey <> reference year: 3
# LFS <> description: 3
# International Migration Organization Displacement Tracking Matrix dataset <> reference year: 3
# survey data <> geography: 3
# micro-level datasets <> data source: 3
# TIMSS <> geography: 3
# DHS <> description: 3
# DHS <> geography: 3
# Integrated Household Survey <> reference year: 3
# European Social Survey <> reference year: 3
# Penn World Tables <> reference year: 3
# SRHCS <> geography: 3
# DHS <> reference year: 3
# IDP study <> description: 3
# PISA <> reference year: 3
# Stringency Index <> geography: 3
# EFW index <> data type: 3
# EFW index <> reference year: 3
# Penn World Tables <> acronym: 2
# Penn World Tables <> publisher: 2
# Penn World Tables <> publication year: 2
# VenRePs-Kids <> description: 2
# VenRePs-Kids <> geography: 2
# proGres <> data type: 2
# Home Visits survey <> reference year: 2
# proGres <> description: 2
# DHS Program <> publisher: 2
# RHCS <> geography: 2
# Demographic and Health Survey <> acronym: 2
# administrative data <> reference year: 2
# administrative data <> geography: 2
# IDP Survey <> geography: 2
# national consumption surveys <> data type: 2
# World Development Indicators <> data type: 2
# World Development Indicators <> reference year: 2
# World Development Indicators <> publisher: 2
# World Development Indicators <> acronym: 2
# Polity IV dataset <> data type: 2
# GROWup <> description: 2
# UNHCR Global Trends <> reference year: 2
# NLSS <> reference year: 2
# microdata on FDPs <> data source: 2
# Barro-Lee <> description: 2
# conﬂict events data set <> geography: 2
# conﬂict events data set <> reference year: 2
# Annual ﬁrm entry data <> description: 2
# Socioeconomic Survey <> geography: 2
# Socioeconomic Survey <> publisher: 2
# Socioeconomic Survey <> publication year: 2
# Socioeconomic Survey <> description: 2
# Journal of Development Economics <> geography: 2
# TIMSS <> reference year: 2
# RDHS <> description: 2
# Armed Conflict Survey <> reference year: 2
# ACLED <> description: 2
# ACLED <> data type: 2
# ACLED <> data source: 2
# Labor Force Survey <> data type: 2
# Linking Ethnic Data from Africa <> description: 2
# Integrated Household Survey <> data type: 2
# VHLSS <> reference year: 2
# HEIS <> description: 2
# Labor Force Survey <> acronym: 2
# HEIS <> geography: 2
# Crisis Response Study <> data type: 2
# DTM ’ s Master Lists <> publisher: 2
# DTM ’ s Master Lists <> version: 2
# DTM ’ s Master Lists <> publication year: 2
# socio-economic household surveys <> publisher: 2
# household survey <> publisher: 2
# GROWup <> data type: 2
# Database of Political Institutions <> acronym: 2
# Polity IV dataset <> geography: 2
# JLMPS <> description: 2
# Jordan Population and Family Health Survey <> publisher: 2
# World Bank database <> geography: 2
# JLMPS <> data type: 2
# RUV <> description: 1
# RUV <> geography: 1
# RUV <> publisher: 1
# RUV <> publication year: 1
# surveys given to migrants who were forcefully displaced <> reference year: 1
# unique dataset on refugee camps <> description: 1
# unique dataset on refugee camps <> geography: 1
# Afrobarometer Survey <> data type: 1
# Afrobarometer Survey <> geography: 1
# Afrobarometer Survey <> reference year: 1
# migration data <> publisher: 1
# migration data <> publication year: 1
# proGres <> geography: 1
# proGres <> acronym: 1
# proGres <> reference year: 1
# Home Visits survey <> geography: 1
# Home Visits survey <> version: 1
# Home Visits survey <> acronym: 1
# proGres <> publisher, Home Visits survey <> publisher: 1
# proGres <> data source, Home Visits survey <> data source: 1
# Poll 14 <> data type: 1
# Poll 15 <> description: 1
# DHS Program <> description: 1
# MICS <> publisher: 1
# MICS <> description: 1
# population register <> description: 1
# population register <> data type: 1
# Armed Conflict Location and Events Database <> data type: 1
# ESS3 <> geography: 1
# ess2 <> description, ess3 <> description: 1
# EHCVM <> geography: 1
# Researcher Coded dataset <> data type: 1
# monthly data from OCHA <> data type: 1
# monthly data from OCHA <> publisher: 1
# monthly data from OCHA <> publication year: 1
# Refugee and Host Communities Household Survey <> geography: 1
# Refugee and Host Communities Household Survey <> reference year: 1
# Refugee and Host Communities Household Survey <> acronym: 1
# RHCS <> description: 1
# Uganda National Household Survey <> acronym: 1
# UNHS <> publisher: 1
# UNHS <> description, RCHS <> description: 1
# UNHS <> data type, RCHS <> data type: 1
# Demographic and Health Survey <> geography: 1
# Demographic and Health Survey <> description: 1
# Jordan Labor Market Panel Survey <> reference year: 1
# Jordan Labor Market Panel Survey <> publisher: 1
# Jordan Labor Market Panel Survey <> publication year: 1
# JLMPS <> publisher: 1
# unique longitudinal dataset <> description: 1
# unique longitudinal dataset <> geography: 1
# unique longitudinal dataset <> reference year: 1
# unique longitudinal dataset <> data type: 1
# Foreign Investment During Recovery <> data type: 1
# Gallup World Poll <> acronym: 1
# Gallup World Poll <> data type: 1
# Gallup World Poll <> description: 1
# Skills Profile Survey <> publication year: 1
# IDP Survey <> publication year: 1
# High Frequency Survey <> geography: 1
# High Frequency Survey <> publication year: 1
# SYPJ <> description: 1
# CMM <> description: 1
# CMM <> publisher: 1
# CMM <> reference year: 1
# UNHCR refugee data <> description: 1
# UNHCR refugee data <> geography: 1
# national consumption surveys <> publisher: 1
# national consumption surveys <> publication year: 1
# FDP datasets <> description: 1
# FDP datasets <> publisher: 1
# FDP datasets <> publication year: 1
# GWP <> geography: 1
# UNHCR dataset <> description: 1
# survey and administrative data <> description: 1
# survey and administrative data <> geography: 1
# survey and administrative data <> publisher: 1
# survey and administrative data <> reference year: 1
# Firm Longitudinal Data <> publisher: 1
# Firm Longitudinal Data <> geography: 1
# Firm Longitudinal Data <> description: 1
# monthly data <> reference year: 1
# monthly data <> description: 1
# monthly data <> data type: 1
# UNCHR Global Trends <> geography: 1
# Education Management Information Systems <> description: 1
# Uganda Education Management Information Systems <> description: 1
# Education Management Information Systems <> geography: 1
# Structural Surveys <> geography: 1
# World Bank survey <> description: 1
# SISMIGRA <> geography, STIMAR <> geography: 1
# SISMIGRA <> publisher, STIMAR <> publisher: 1
# study dataset <> data type: 1
# study dataset <> reference year: 1
# reference year: 1
# study dataset <> description: 1
# survey data <> data type: 1
# EPR-ER <> description: 1
# 2001 parish boundaries <> data type: 1
# parish boundaries <> reference year: 1
# National Service Delivery Survey <> geography: 1
# National Service Delivery Survey <> acronym: 1
# National Service Delivery Survey <> reference year: 1
# National Service Delivery Survey <> description: 1
# NSDS <> data type: 1
# IHSES-II <> version: 1
# IHSES-II <> description: 1
# LFS <> publisher: 1
# FDP datasets <> data type: 1
# micro-level household surveys <> data source: 1
# non-FDP micro-level datasets <> data source: 1
# FDP micro-level dataset <> data type: 1
# FDP micro-level dataset <> reference year: 1
# International Migration Organization Displacement Tracking Matrix dataset <> description: 1
# conﬂict events data set <> description: 1
# Profile Global Registration System <> publisher, Jordan Home Visits <> publisher: 1
# Profile Global Registration System <> acronym: 1
# Jordan Home Visits <> version: 1
# Jordan Home Visits <> acronym: 1
# ProGres <> geography: 1
# ProGres <> description: 1
# ProGres <> reference year: 1
# Household Labor Force Survey <> description: 1
# Household Labor Force Survey <> geography: 1
# Household Labor Force Survey <> reference year: 1
# VenRepS-Kids <> geography: 1
# VenRepS-Kids <> reference year: 1
# ESS2 <> data type: 1
# Integrated Household and Budget survey <> geography: 1
# Integrated Household and Budget survey <> publisher: 1
# Data on Anti-Immigrant Violence <> description: 1
# Data on Anti-Immigrant Violence <> geography: 1
# geo-referenced event dataset <> description: 1
# geo-referenced event dataset <> publisher: 1
# Kakuma Socioeconomic Survey <> reference year: 1
# Socioeconomic Profiling Survey <> reference year: 1
# socioeconomic survey <> geography: 1
# Socioeconomic Profiling Survey <> publisher: 1
# Socioeconomic Profiling Survey <> publication year: 1
# Socioeconomic Survey <> reference year: 1
# Panel Surveys <> description: 1
# Panel Surveys <> publisher: 1
# Panel Surveys <> publication year: 1
# national labor force survey <> description: 1
# national labor force survey <> geography: 1
# national labor force survey <> data type: 1
# ESS3 <> data type: 1
# TIMSS <> description: 1
# LFSs <> reference year: 1
# LFS <> data type, HEIS <> data type: 1
# Armed Conflict Survey <> description: 1
# Armed Conflict Survey <> publisher: 1
# Armed Conflict Survey <> publication year: 1
# ACLED <> publisher: 1
# ACLED <> publication year: 1
# ACLED <> version: 1
# ACLED <> data type, UCDP <> data type, Demographic and Health Survey <> data type: 1
# Afrobarometer <> description: 1
# Listening to Displaced People Survey <> description: 1
# Listening to Displaced People Survey <> data type: 1
# EMOP <> reference year: 1
# EMOP <> publisher: 1
# DHS survey <> data type: 1
# DHS survey <> reference year: 1
# DHS survey <> description: 1
# HV <> description: 1
# PG <> data type: 1
# World Development Indicators <> description: 1
# Refugee Finder <> publisher: 1
# Refugee Finder <> publisher, Global Internal Displacement Database <> publisher: 1
# UNCHR and WB MDL <> reference year: 1
# refugee registration data <> description: 1
# refugee registration data <> publisher: 1
# Syrian Refugees and Host Communities Surveys <> data type: 1
# Syrian Refugees and Host Communities Surveys <> reference year: 1
# Syrian Refugees and Host Communities Surveys <> acronym: 1
# focus groups and in-depth interviews <> data type: 1
# Cash Assistance Database <> description: 1
# Voluntary Repatriation Form <> publisher: 1
# Cash Assistance Database <> publisher: 1
# Cash Assistance Database <> reference year: 1
# EPEC survey <> geography: 1
# EPEC survey <> data type: 1
# Linking Ethnic Data from Africa <> data type: 1
# Linking Ethnic Data from Africa <> acronym: 1
# Linking Ethnic Data from Africa <> publisher: 1
# Linking Ethnic Data from Africa <> publication year: 1
# Linking Ethnic Data from Africa <> geography: 1
# EPR-ER dataset <> data type: 1
# Afrobarometer <> data type: 1
# LFS <> data type: 1
# UCDP / PRIO <> description: 1
# household-based surveys <> description: 1
# household-based surveys <> geography: 1
# 1998 Census of Population <> publisher: 1
# Integrated Household Survey <> geography: 1
# labor force survey <> description: 1
# labor force survey <> geography: 1
# labor force survey <> publisher: 1
# labor force survey <> publication year: 1
# Household Power Index <> description: 1
# Household Power Index <> publisher: 1
# Household Power Index <> publication year: 1
# Work Rights Index <> description: 1
# VHLSS <> description: 1
# VHLSS <> geography: 1
# VHLSS <> version: 1
# DWRAP <> description: 1
# Camp Mapping database <> publisher: 1
# UNHCR Camp Mapping database <> description: 1
# UNHCR Camp Mapping database <> reference year: 1
# European Social Survey <> acronym: 1
# European Social Survey <> description: 1
# ESS <> geography: 1
# ESS <> description: 1
# Barro-Lee Educational Attainment dataset <> data type: 1
# Barro-Lee Educational Attainment dataset <> publisher: 1
# Barro-Lee Educational Attainment dataset <> publication year: 1
# GED dataset <> description: 1
# GED dataset <> publisher: 1
# Panel event studies analysis <> description: 1
# Researcher Coded dataset <> description: 1
# Barro-Lee <> geography: 1
# Barro-Lee <> publication year: 1
# Barro-Lee <> reference year: 1
# World Bank ’ s Edstats <> data type: 1
# Household and labor force surveys <> geography: 1
# Household and labor force surveys <> data type: 1
# match_Named: 1
# HS <> publisher: 1
# HS <> description: 1
# HS <> data type: 1
# JC <> description: 1
# Labor Force Survey <> description: 1
# Labor Force Survey <> publisher: 1
# surveys and interviews <> data type: 1
# surveys and interviews <> publisher: 1
# surveys and interviews <> publication year: 1
# IDP Profiling Survey <> geography: 1
# IDP Profiling Survey <> publication year: 1
# IDP Profiling Survey <> data type: 1
# Kagera Health and Development Survey <> publisher: 1
# Kagera Health and Development Survey <> publication year: 1
# Kagera Health and Development Survey <> data type: 1
# Kagera Health and Development Survey <> version: 1
# Kagera Health and Development Survey <> reference year: 1
# Kagera Health and Development Survey <> acronym: 1
# HEIS <> data type: 1
# World Integrated Trade Solutions <> acronym: 1
# World Integrated Trade Solutions <> geography: 1
# wits <> reference year: 1
# Mogadishu Household Survey <> geography, Puntland Household Survey <> geography: 1
# Mogadishu Household Survey <> description: 1
# Puntland Household Survey <> publisher: 1
# Puntland Household Survey <> description: 1
# IDP study <> geography: 1
# Crisis Response Study <> geography: 1
# Crisis Response Study <> description: 1
# Iraq Crisis Response Study <> description: 1
# Crisis Response Study <> publisher: 1
# Crisis Response Study <> publication year: 1
# Crisis Response Study <> reference year: 1
# Cadastro Unico <> geography: 1
# Cadastro Unico <> reference year: 1
# Cadastro Unico <> data type: 1
# dataset of central business district office rents <> publisher: 1
# dataset of central business district office rents <> publication year: 1
# dataset of central business district office rents <> reference year: 1
# dataset of central business district office rents <> description: 1
# dataset of central business district office rents <> data type: 1
# natural disasters hotspot dataset <> publisher: 1
# natural disasters hotspot dataset <> publication year: 1
# natural disasters hotspot dataset <> description: 1
# DTM ’ s Master Lists <> data type: 1
# DTM ’ s Integrated Location Assessments <> data type: 1
# DTM ’ s Integrated Location Assessments <> publisher: 1
# DTM ’ s Integrated Location Assessments <> acronym: 1
# DTM ’ s Return Index <> publisher: 1
# Conflict Termination dataset <> publisher: 1
# Conflict Termination dataset <> data source: 1
# population census <> reference year: 1
# census of private schooling <> reference year: 1
# census of private schooling <> description: 1
# census of private schooling <> geography: 1
# household survey <> description: 1
# Refugee Economies Dataset <> description: 1
# Refugee Economies Dataset <> data type: 1
# in-person data <> description: 1
# in-person data <> reference year: 1
# GROWup <> reference year: 1
# PISA <> data type: 1
# TIMSS <> data type: 1
# world bank dataset <> data type: 1
# unit record data sets on IDPs <> data type: 1
# unit record data sets on IDPs <> data source: 1
# education registry <> geography: 1
# education registry <> reference year: 1
# Polity IV dataset <> reference year: 1
# measures of women ’ s empowerment <> geography: 1
# measures of women ’ s empowerment <> publisher: 1
# measures of women ’ s empowerment <> publication year: 1
# Jordan Population and Family Health Survey: 1
# Jordan Population and Family Health Survey <> geography: 1
# Demographic and Health Survey: 1
# Jordan Population and Family Health Survey <> publication year: 1
# LSMS-type household-surveys <> description: 1
# BPC <> description: 1
# Single Registry of Social Programs <> publisher: 1
# Single Registry of Social Programs <> description: 1
# Stringency Index <> publisher: 1
# Stringency Index <> description: 1
# Stringency Index <> reference year: 1
# Economic Freedom of the World <> publisher: 1
# Economic Freedom of the World <> publication year: 1
# Economic Freedom of the World <> acronym: 1
# statistical population online dataset <> geography: 1
# statistical population online dataset <> reference year: 1
# statistical population online dataset <> publisher: 1
# statistical population online dataset <> publication year: 1
# United Nations Commodity Trade Statistics Database <> description: 1
# TLSS <> version: 1
# Living Standard Measurement Surveys <> description: 1
# Living Standard Measurement Surveys <> geography: 1
# Living Standard Measurement Surveys <> acronym: 1
# Living Standard Measurement Surveys <> publication year: 1
# Agricultural Sample Survey <> description: 1
# Agricultural Sample Survey <> reference year: 1
# label: 1
# Agricultural Sample Survey <> geography: 1
# World Bank database <> publisher: 1
# World Bank database <> publication year: 1
# Domestic Violence Module <> description: 1
# S-RLS <> description: 1
# S-RLS <> data type: 1
# JLMPS <> geography: 1
# Socio-demographic data <> geography: 1
# VRF <> data type: 1
# VRF <> description: 1
# post-return surveys <> data type: 1
# SRQ-20 <> description: 1
# SRQ-20 <> geography: 1
# SRQ-20 <> publisher: 1
# SRQ-20 <> publication year: 1
# Cadastro ´ Unico <> data type: 1
# Cadastro ´ Unico <> reference year: 1
# EFW index <> description: 1
# EFW index <> publisher: 1
# EFW index <> publication year: 1

# %%
from pydantic import BaseModel, RootModel
from typing import List
import random

class Entity(BaseModel):
    text: str
    label: str

class SyntheticDatasetResponse(BaseModel):
    text: str
    entities: List[Entity]

class SyntheticDatasetBatch(BaseModel):
    RootModel: List[SyntheticDatasetResponse]

# %%
train_df.head()
# Out:
#    idx                                               text  \
# 0    0  displacement has been decreasing slowly in con...
# 1    1  non-cooperative behaviors that lead to the eme...
# 2   10  3 Figure 1 Emigration is highest for middle-in...
# 3  100  displaced children and adolescents residing in...
# 4  101  9 and the Syrian crisis , the UNHCR and the Wo...
#
#                                       tokenized_text  \
# 0  [displacement, has, been, decreasing, slowly, ...
# 1  [non-cooperative, behaviors, that, lead, to, t...
# 2  [3, Figure, 1, Emigration, is, highest, for, m...
# 3  [displaced, children, and, adolescents, residi...
# 4  [9, and, the, Syrian, crisis, ,, the, UNHCR, a...
#
#                                                  ner  validated  \
# 0  [(19, 19, named dataset), (24, 28, RUV <> desc...       True
# 1  [(41, 51, unique dataset on refugee camps <> d...       True
# 2  [(15, 16, unnamed dataset), (18, 19, migration...       True
# 3  [(17, 17, named dataset), (40, 68, VenRePs-Kid...       True
# 4  [(51, 51, proGres <> geography), (52, 52, name...       True
#
#                                       ner_normalized  \
# 0  [(19, 19, named dataset), (24, 28, RUV <> desc...
# 1  [(41, 51, unique dataset on refugee camps <> d...
# 2  [(15, 16, unnamed dataset), (18, 19, migration...
# 3  [(17, 17, named dataset), (40, 68, VenRePs-Kid...
# 4  [(51, 51, proGres <> geography), (52, 52, name...
#
#                                       extracted_text  \
# 0  [{'text': 'RUV', 'label': 'named dataset'}, {'...
# 1  [{'text': 'assess the consequences of forced m...
# 2  [{'text': 'migration data', 'label': 'unnamed ...
# 3  [{'text': 'VenRePs-Kids', 'label': 'named data...
# 4  [{'text': 'Jordan', 'label': 'proGres <> geogr...
#
#                                             entities
# 0  [{'text': 'RUV', 'label': 'named dataset'}, {'...
# 1  [{'text': 'assess the consequences of forced m...
# 2  [{'text': 'migration data', 'label': 'unnamed ...
# 3  [{'text': 'VenRePs-Kids', 'label': 'named data...
# 4  [{'text': 'Jordan', 'label': 'proGres <> geogr...

# %%
train_df['sentence'] = train_df['tokenized_text'].map(join_tokens)

# %%
train_df.to_csv("150idx_train_data.csv", index=False)

# %%
# Parameters
SAMPLES_PER_DOMAIN = 1   # how many synthetic samples to generate per domain
N_SHOTS = 1               # how many few-shot examples per prompt
BATCH_SIZE = 50           # for downstream processing

# List of domains
domains = [
    "climate change",
   # "meteorology & weather modeling",
    "geospatial & remote sensing",
   # "oceanography & marine science",
   # "environmental science",
   # "hydrology & water resource management",
   # "biodiversity & ecosystem analysis",
   # "air pollution & emissions monitoring",
   # "energy & sustainability studies",
    "forestry & deforestation monitoring",
    "agriculture & food security",
    "carbon footprint & greenhouse gas inventories",
   # "macroeconomics & development studies",
    "global trade & commerce",
    "poverty & inequality research",
    "public finance & taxation",
    "monetary policy & inflation",
   # "sustainable finance & green investment",
    "microfinance & small business development",
    "labor markets & employment studies",
    "public policy & governance",
    #"urban development & city planning",
   # "disaster response & climate resilience",
   # "education & human capital development",
   # "social protection & welfare programs",
    "migration & refugee studies",
    "international aid & development policy",
   # "infrastructure development & transport economics",
   # "sustainable development goals (SDGs) monitoring",
    "World Bank & IMF policy research",
    #"refugee"
]
# domains = [
#     "meteorology & weather modeling",
#     "oceanography & marine science",
#     "environmental science",
#     "hydrology & water resource management",
#     "biodiversity & ecosystem analysis",
#     "air pollution & emissions monitoring",
#     "energy & sustainability studies",
#     "macroeconomics & development studies",
#     "sustainable finance & green investment",
#     "urban development & city planning",
#     "disaster response & climate resilience",
#     "education & human capital development",
#     "social protection & welfare programs",
#     "infrastructure development & transport economics",
#     "sustainable development goals (SDGs) monitoring",
#     "refugee",
# ]

# %%
import random

all_prompts = []

for _, row in train_df.iterrows():
    text = row["sentence"].strip()
    entities = row["entities"]

    # Sample 3 distinct domains
    sampled_domains = random.sample(domains, k=3)

    # Build entity display lines
    entity_lines = "\n".join(
        f"{i+1}. \"{ent['text']}\" ({ent['label']})"
        for i, ent in enumerate(entities)
    )

    # Build the entity JSON block (same across all)
    json_entities_example = ",\n        ".join(
        '{ "text": "...", "label": "' + ent["label"] + '" }'
        for ent in entities
    )

    # Example block
    example_section = f"""Example
---------
Text:
{text}

Entities (MUST have exactly {len(entities)} entries, in this order and format):
{entity_lines}
"""

    # Format sampled domains nicely
    domain_section = "\n".join(f"- {domain}" for domain in sampled_domains)

    prompt = f"""
Given the following example data, generate **three** synthetic examples using three different domains sampled below.
**IMPORTANT** The goal of the generation of synthetic examples is to extract dataset mentions in the text. Make sure to comply with the instructions below.

### Instructions:
1. Each generated text should match the structure and length of the original input.
2. Use exactly the same number of entity mentions, and the same labels in the same order.
3. Each output should reflect the theme of the domain it was generated for.
4. **Embed each entity string verbatim** in your generated text, matching its usage.
5. **Do not invent new dataset names** for `named dataset` entries — use only real-world or plausible names.
6. Output a list of 3 items, each with a `"text"` and `"entities"`.

### Allowed Labels:
- named dataset
- unnamed dataset
- vague dataset
- citation data source
- document data source

### Sampled Domains:
{domain_section}

{example_section}

### Output Format:
Return a list of 3 examples like this:

[
  {{
    "text": "...",  // related to: {sampled_domains[0]}
    "entities": [
        {json_entities_example}
    ]
  }},
  {{
    "text": "...",  // related to: {sampled_domains[1]}
    "entities": [
        {json_entities_example}
    ]
  }},
  {{
    "text": "...",  // related to: {sampled_domains[2]}
    "entities": [
        {json_entities_example}
    ]
  }}
]
""".strip()

    all_prompts.append(prompt)

# %%
len(all_prompts)
# Out:
# 136

# %%
all_prompts[2]
# Out:
# 'Given the following example data, generate **three** synthetic examples using three different domains sampled below.\n**IMPORTANT** The goal of the generation of synthetic examples is to extract dataset mentions in the text. Make sure to comply with the instructions below.\n\n### Instructions:\n1. Each generated text should match the structure and length of the original input.\n2. Use exactly the same number of entity mentions, and the same labels in the same order.\n3. Each output should reflect the theme of the domain it was generated for.\n4. **Embed each entity string verbatim** in your generated text, matching its usage.\n5. **Do not invent new dataset names** for `named dataset` entries — use only real-world or plausible names.\n6. Output a list of 3 items, each with a `"text"` and `"entities"`.\n\n### Allowed Labels:\n- named dataset\n- unnamed dataset\n- vague dataset\n- citation data source\n- document data source\n\n### Sampled Domains:\n- carbon footprint & greenhouse gas inventories\n- public finance & taxation\n- poverty & inequality research\n\nExample\n---------\nText:\n3 Figure 1 Emigration is highest for middle-income countries Sources: Original estimation based on migration data from UN DESA 2020 and GDP data from the Penn World Tables ( PWT ) 10. 0 ( Feenstra, Inklaar, and Timmer 2015 ). Note: The figure plots the relationship between total migrant stock ( as a percentage of origin country population ) in 2020 against the per capita GDP ( in constant 2017 US dollars in purchasing power parity terms, 2017 PPP $ ) in 2020. The solid line presents a locally linear fit. GDP for 2020 is calculated by applying the GDP growth rate applied to the 2019 GDP from PWT 10. 0. Emigration is capped at 30 percent for countries with higher emigration rates for the scatterplot. Data labels use International Organization for Standardization ( ISO ) country codes. However, early empirical research on this relationship was limited by lack of data. Early results relied on a cross-sectional relationship or used only a subset of countries for which reliable historic data were available ( such as the member countries of the Organisation for Economic\n\nEntities (MUST have exactly 13 entries, in this order and format):\n1. "migration data" (unnamed dataset)\n2. "UN DESA" (migration data <> publisher)\n3. "2020" (migration data <> publication year)\n4. "GDP data" (Penn World Tables <> data type)\n5. "Penn World Tables" (named dataset)\n6. "PWT" (Penn World Tables <> acronym)\n7. "Feenstra , Inklaar , and Timmer" (Penn World Tables <> publisher)\n8. "2015" (Penn World Tables <> publication year)\n9. "2020" (PWT <> reference year)\n10. "2020" (PWT <> reference year)\n11. "2020" (PWT <> reference year)\n12. "2019" (PWT <> reference year)\n13. "PWT" (named dataset)\n\n\n### Output Format:\nReturn a list of 3 examples like this:\n\n[\n  {\n    "text": "...",  // related to: carbon footprint & greenhouse gas inventories\n    "entities": [\n        { "text": "...", "label": "unnamed dataset" },\n        { "text": "...", "label": "migration data <> publisher" },\n        { "text": "...", "label": "migration data <> publication year" },\n        { "text": "...", "label": "Penn World Tables <> data type" },\n        { "text": "...", "label": "named dataset" },\n        { "text": "...", "label": "Penn World Tables <> acronym" },\n        { "text": "...", "label": "Penn World Tables <> publisher" },\n        { "text": "...", "label": "Penn World Tables <> publication year" },\n        { "text": "...", "label": "PWT <> reference year" },\n        { "text": "...", "label": "PWT <> reference year" },\n        { "text": "...", "label": "PWT <> reference year" },\n        { "text": "...", "label": "PWT <> reference year" },\n        { "text": "...", "label": "named dataset" }\n    ]\n  },\n  {\n    "text": "...",  // related to: public finance & taxation\n    "entities": [\n        { "text": "...", "label": "unnamed dataset" },\n        { "text": ".. ...

# %%
from tqdm import tqdm

def generate_from_prompts(prompts, model="gpt-4o-mini", temperature=0.2, top_p=0.95):
    """
    Calls GPT-4o-mini in batches and parses the generated outputs.
    
    Args:
        prompts (list): List of generated prompts.
        model (str): Model to use for generation.
        temperature (float): Controls randomness in output.
        top_p (float): Controls diversity in sampling.

    Returns:
        tuple: (Generated JSON outputs, tokenized processed output)
    """
    all_outputs = []
    processed_output = []
    with tqdm(total=len(prompts), desc="Generating Synthetic Data") as pbar:
        for prompt in prompts:
            try:
                completion = client.beta.chat.completions.parse(
                    model=model,
                    temperature=0.2,
                    messages=[{"role": "system", "content": prompt}],
                    response_format=SyntheticDatasetBatch,
                )
    
                # Parse JSON response
                json_output = completion.choices[0].message.parsed
                extracted_output = extract_entities(json_output.model_dump()['RootModel'])
                all_outputs.extend(json_output)
                processed_output.extend(extracted_output)
    
            except Exception as e:
                print(f"Error processing prompt: {e}")
                continue
            pbar.update(1)  # Update progress bar

    return all_outputs, processed_output

# %%
def extract_entities(parsed_batch):
    processed = []
    for item in parsed_batch:
        # Handle either Pydantic models or plain dicts
        text = item.text if hasattr(item, "text") else item["text"]
        entities = item.entities if hasattr(item, "entities") else item["entities"]
        processed.append({
            "text": text,
            "entities": [ent.dict() if hasattr(ent, "dict") else ent for ent in entities]
        })
    return processed

# %%
len(all_prompts)
# Out:
# 136

# %%
# Generate and parse using your structured LLM pipeline
all_outputs, processed_outputs = generate_from_prompts(
    all_prompts,
    model="gpt-4o-mini",
    temperature=0.2,
    top_p=0.95
)
# Out:
# Generating Synthetic Data: 100%|██████████| 1/1 [00:18<00:00, 18.03s/it]

# %%
all_prompts[0]
# Out:
# 'Given the following example data, generate **three** synthetic examples using three different domains sampled below.\n**IMPORTANT** The goal of the generation of synthetic examples is to extract dataset mentions in the text. Make sure to comply with the instructions below.\n\n### Instructions:\n1. Each generated text should match the structure and length of the original input.\n2. Use exactly the same number of entity mentions, and the same labels in the same order.\n3. Each output should reflect the theme of the domain it was generated for.\n4. **Embed each entity string verbatim** in your generated text, matching its usage.\n5. **Do not invent new dataset names** for `named dataset` entries — use only real-world or plausible names.\n6. Output a list of 3 items, each with a `"text"` and `"entities"`.\n\n### Allowed Labels:\n- named dataset\n- unnamed dataset\n- vague dataset\n- citation data source\n- document data source\n\n### Sampled Domains:\n- labor markets & employment studies\n- climate change\n- international aid & development policy\n\nExample\n---------\nText:\ndisplacement has been decreasing slowly in conjunction with a softening of conﬂict intensity and violence. 8 Data from RUV also suggests that the cumulative population of forced migrants is balanced in terms of gender ( 51 percent women ) and that most are of working age. Colombia ’ s forced migrants are also young. In particular, 39 percent of forcefully displaced individuals were 15 years old or younger at the time of displacement, this percentage is disproportionately larger than this age group within the population of Colombia as a whole ( 28 percent ). Indeed, 15. 5 percent of forced migrants were younger than 5 years of age at the time of migration. Households also tend to be bigger as several members of the extended family tend to live together to save on housing costs ( Unidad para la Atenci ´ on y Reparaci ´ on de V ´ ıctimas, 2013 ). Previous studies, using surveys given to migrants who were forcefully displaced, also report that this population has low education 2005. Many of the combatants that had been part of the AUC,\n\nEntities (MUST have exactly 7 entries, in this order and format):\n1. "RUV" (named dataset)\n2. "cumulative population of forced migrants" (RUV <> description)\n3. "Colombia" (RUV <> geography)\n4. "Unidad para la Atenci ´ on y Reparaci ´ on de V ´ ıctimas" (RUV <> publisher)\n5. "2013" (RUV <> publication year)\n6. "surveys given to migrants who were forcefully displaced" (unnamed dataset)\n7. "2005" (surveys given to migrants who were forcefully displaced <> reference year)\n\n\n### Output Format:\nReturn a list of 3 examples like this:\n\n[\n  {\n    "text": "...",  // related to: labor markets & employment studies\n    "entities": [\n        { "text": "...", "label": "named dataset" },\n        { "text": "...", "label": "RUV <> description" },\n        { "text": "...", "label": "RUV <> geography" },\n        { "text": "...", "label": "RUV <> publisher" },\n        { "text": "...", "label": "RUV <> publication year" },\n        { "text": "...", "label": "unnamed dataset" },\n        { "text": "...", "label": "surveys given to migrants who were forcefully displaced <> reference year" }\n    ]\n  },\n  {\n    "text": "...",  // related to: climate change\n    "entities": [\n        { "text": "...", "label": "named dataset" },\n        { "text": "...", "label": "RUV <> description" },\n        { "text": "...", "label": "RUV <> geography" },\n        { "text": "...", "label": "RUV <> publisher" },\n        { "text": "...", "label": "RUV <> publication year" },\n        { "text": "...", "label": "unnamed dataset" },\n        { "text": "...", "label": "surveys given to migrants who were forcefully displaced <> reference year" }\n    ]\n  },\n  {\n    "text": "...",  // related to: international aid & development policy\n    "entities": [\n        { "text": "...", "label": "named dataset" },\n        { "text": "...", "label": "RUV  ...

# %%
len(processed_outputs)
# Out:
# 3

# %%
print(processed_outputs[0])
# Out:
# {'text': 'The recent analysis of labor trends indicates that the employment rate has been steadily increasing, particularly among younger demographics. 7 Data from the BLS shows that the number of job openings has reached an all-time high, with a significant portion of these positions being filled by individuals aged 18 to 24. In particular, the BLS report highlights that 45 percent of new hires in the last quarter were from this age group, which is a notable increase compared to previous years. Furthermore, 12 percent of these new employees were hired for roles in technology and healthcare sectors ( U.S. Bureau of Labor Statistics, 2022 ). Previous studies, utilizing data from job placement agencies, also indicate that this demographic is increasingly seeking flexible work arrangements. Many of these young workers are prioritizing jobs that offer remote work options, as indicated by a survey conducted in 2021.', 'entities': [{'text': 'BLS', 'label': 'named dataset'}, {'text': 'number of job openings', 'label': 'BLS <> description'}, {'text': '18 to 24', 'label': 'BLS <> geography'}, {'text': 'U.S. Bureau of Labor Statistics', 'label': 'BLS <> publisher'}, {'text': '2022', 'label': 'BLS <> publication year'}, {'text': 'data from job placement agencies', 'label': 'unnamed dataset'}, {'text': '2021', 'label': 'data from job placement agencies <> reference year'}]}

# %%
print(processed_outputs[1])
# Out:
# {'text': "Recent climate models indicate that global temperatures are set to rise significantly over the next few decades. 9 Data from the IPCC suggests that the average global temperature could increase by 1.5 degrees Celsius by 2030 if current trends continue. This alarming projection has raised concerns among scientists, particularly regarding the impact on polar ice caps and sea levels. Notably, the IPCC report emphasizes that 70 percent of the world's glaciers are retreating at unprecedented rates ( Intergovernmental Panel on Climate Change, 2021 ). Previous assessments, based on satellite imagery, also reveal that coastal cities are at high risk of flooding due to rising sea levels. Many regions are now prioritizing climate resilience strategies, as highlighted in a study conducted in 2020.", 'entities': [{'text': 'IPCC', 'label': 'named dataset'}, {'text': 'average global temperature', 'label': 'IPCC <> description'}, {'text': 'polar ice caps', 'label': 'IPCC <> geography'}, {'text': 'Intergovernmental Panel on Climate Change', 'label': 'IPCC <> publisher'}, {'text': '2021', 'label': 'IPCC <> publication year'}, {'text': 'satellite imagery', 'label': 'unnamed dataset'}, {'text': '2020', 'label': 'satellite imagery <> reference year'}]}

# %% [markdown]
# ### Save for training

# %%
import json
output_file = "synthetic_data_refugee_relations_150idx.json"

with open(output_file, "w", encoding="utf-8") as f:
    json.dump(processed_outputs, f, indent=2, ensure_ascii=False)
